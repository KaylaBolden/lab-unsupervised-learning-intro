# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
# %matplotlib inline
moons = make_moons(n_samples=100, shuffle=True, noise=0.05)
plt.scatter(moons[0][:,0], moons[0][:,1])

# %%
print(type(moons))
print(len(moons))
print(len(moons[0]))
print(len(moons[0][0]))
# Out:
# <class 'tuple'>
# 2
# 100
# 2

# %%
# moons[0][:,0]

# %%
# moons[0]

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.18, min_samples=5).fit(moons[0])
dbscan.labels_
# Out:
# array([ 0,  1,  0,  2,  3,  2,  5,  0,  3,  1,  0,  4, -1,  5,  0, -1,  0,
#         0,  5,  6,  4,  0,  3,  0, -1,  0,  0,  5,  5,  5,  6,  5,  5,  2,
#         4,  0,  5,  5,  1,  1,  0,  2,  0,  1,  6,  0,  6,  6,  0,  3,  5,
#         0,  1,  4,  5,  3, -1,  6,  4,  0,  1,  1,  1,  0,  1,  6,  1,  2,
#         2,  6,  0, -1, -1,  1,  1,  1,  6,  4,  0,  2,  5,  5,  0,  1,  0,
#         0,  6,  0,  0,  4,  0,  0,  2,  0,  1,  2,  1,  5,  5,  1])

# %%
plt.scatter(moons[0][:,0], moons[0][:,1], c=dbscan.labels_)
